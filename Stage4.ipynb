# %%
from keras.preprocessing.image import ImageDataGenerator
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from keras.layers import Convolution2D as conv2D
from keras.layers import MaxPooling2D
from keras.layers import Activation,Dropout, Flatten, Dense
from tensorflow.keras.preprocessing import image
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt
import os , sys
from PIL import Image as im
from os import listdir

from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop , Adam, SGD
from tensorflow.keras import Model
from keras.layers import GlobalAveragePooling2D
from sklearn.model_selection import train_test_split

import cv2
import glob    # glob (short for global) is used to return all file paths that match a specific pattern.
import random
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn import metrics
from keras.callbacks import EarlyStopping

# %% [markdown]
# **ResNet50**

# %%
IMG_SHAPE=(224,224,3)
IMG_SIZE = (224, 224)
#IMG_SHAPE = (150, 150, 3) #(150,150) were used before in Inception V3

# %%
#######################################################
#Get the convolution base of a Pre-Trained CNN (here it is ResNet50)
#######################################################
base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
#Store the number of top layers from the convolution base you want to discard in
#the variable discard_layers
discard_layers = 33 # i.e 8, 11, 21, 22, 33  at 33 i got max accuracy

#x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
#discard few top layers of convolution base and add global
#average pooling layer on top of it.
x = tf.keras.layers.GlobalAveragePooling2D()(base_model.layers[-discard_layers].output)

# %%
updated_model = tf.keras.models.Model(inputs=base_model.input,
                              outputs= x)

# %%
#See all the layers of a model
updated_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  global_average_pooling2d_2  (None, 1024)                 0         ['conv4_block6_out[0][0]']
#   (GlobalAveragePooling2D)
#
# ==================================================================================================
# Total params: 8589184 (32.77 MB)
# Trainable params: 8558592 (32.65 MB)
# Non-trainable params: 30592 (119.50 KB)
# __________________________________________________________________________________________________

# %%
num_layers = len(updated_model.layers)
print(f'The model has {num_layers} layers.')
# Out:
# The model has 144 layers.

# %% [markdown]
# **DATA Pre-Processing**

# %%
Normal = []
for filename in glob. glob('/content/drive/MyDrive/DataSet_CBIS-DDSM/Mass_Train_Set/BENIGN_WITHOUT_CALLBACK/*.jpg'):
  n= cv2.imread(filename)
  img=np.array(n)
  n1 = cv2.resize(img , IMG_SIZE)
  Normal. append(n1)
  n= tf.image.flip_up_down(n1)
  Normal. append(n)
  n= tf.image.flip_left_right(n1)
  Normal. append(n)
  n= tf.image.adjust_brightness(n1, delta=0.2)
  Normal. append(n)
  n= tf.image.adjust_contrast (n1, 2.25 )
  Normal. append(n)
  n= tf.image.rot90 (n1, k=1 )
  Normal.append(n)
  n = tf.image.rot90 (n1, k=2 )
  Normal.append(n)
  n= tf.image.rot90 (n1, k=3 )
  Normal.append(n)
Normal=np.array(Normal)

# %%
Benign = []
for filename in glob. glob('/content/drive/MyDrive/DataSet_CBIS-DDSM/Mass_Train_Set/BENIGN/*.jpg'):
  n= cv2.imread(filename)
  img=np.array(n)
  n2 = cv2.resize(img , IMG_SIZE)
  Benign. append(n2)
  n= tf.image.flip_up_down(n2)
  Benign. append(n)
  n= tf.image.flip_left_right(n2)
  Benign. append(n)
  n= tf.image.adjust_brightness(n2, delta=0.2)
  Benign. append(n)
"""  n= tf.image.adjust_contrast (n2, 2.25 )
  Benign. append(n)
  n= tf.image.rot90 (n2, k=1 )
  Benign.append(n)
  n = tf.image.rot90 (n2, k=2 )
  Benign.append(n)
  n= tf.image.rot90 (n2, k=3 )
  Benign.append(n)"""
Benign=np.array(Benign)

# %%
Malignant = []
for filename in glob. glob('/content/drive/MyDrive/DataSet_CBIS-DDSM/Mass_Train_Set/MALIGNANT/*.jpg'):
  n= cv2.imread(filename)
  img=np.array(n)
  n3 = cv2.resize(img , IMG_SIZE)
  Malignant. append(n3)
  n= tf.image.flip_up_down(n3)
  Malignant. append(n)
  n= tf.image.flip_left_right(n3)
  Malignant. append(n)
  n= tf.image.adjust_brightness(n3, delta=0.2)
  Malignant. append(n)
"""  n= tf.image.adjust_contrast (n3, 2.25 )
  Malignant. append(n)
  n= tf.image.rot90 (n3, k=1 )
  Malignant.append(n)
  n = tf.image.rot90 (n3, k=2 )
  Malignant.append(n)
  n= tf.image.rot90 (n3, k=3 )
  Malignant.append(n) """
Malignant=np.array(Malignant)

# %%
print (len(Normal))
print( len(Benign) )
print( len(Malignant))
# Out:
# 664
# 2196
# 2388

# %% [markdown]
# **Training Features Extraction of ResNet50**

# %%
Normal_features_1 = updated_model.predict(Normal, verbose= True)
# Out:
# 21/21 [==============================] - 118s 6s/step

# %%
Benign_features_1 = updated_model.predict(Benign, verbose= True)
# Out:
# 69/69 [==============================] - 388s 6s/step

# %%
Malignant_features_1 = updated_model.predict(Malignant, verbose= True)
# Out:
# 75/75 [==============================] - 420s 6s/step

# %%
print(Benign_features_1.shape)
# Out:
# (2196, 2048)

# %%
print(Normal_features_1[2])
# Out:
# [0.         0.         0.00595283 ... 1.8342158  0.         0.        ]

# %%
Training_features_ResNet50= np.concatenate((Normal_features_1, Benign_features_1, Malignant_features_1))

# %%
print(Training_features_ResNet50.shape)
# Out:
# (5248, 512)

# %% [markdown]
# **Data Labels**

# %%
labels_Normal= np.zeros((664,1))
labels_Benign= np.ones((2196,1))
labels_Malignant= np.zeros((2388,1))

labels_Malignant[:, 0] = 2

# %%
concatenated_labels= np.concatenate((labels_Normal, labels_Benign, labels_Malignant))

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
y_train1 = ohe.fit_transform(concatenated_labels).toarray()

# %% [markdown]
# **Train, Test Split Sklearn**

# %%
X_train, X_test, y_train, y_test = train_test_split (Training_features_ResNet50,y_train1 ,
                                   random_state=0 ,
                                   test_size=0.20,
                                   shuffle=True )
#increase test size to 0.4 and check the results
#increase datasize by merging train and test dataset.

# %% [markdown]
# **Classifier Compilation...........FC Layer**

# %%
model = Sequential()
model.add(Flatten())
#model.add(Dropout(0.2, input_shape=(1024,)))
model.add(Dense(1024, input_shape=(2048,), activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer = RMSprop(learning_rate=0.0001),
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

# %%
# Implement callback function to stop training
# when accuracy reaches e.g. ACCURACY_THRESHOLD = 0.95

ACCURACY_THRESHOLD= 0.95

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
          print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
          self.model.stop_training = True

# %%
callbacks = myCallback()

# %% [markdown]
# **Training on features extracted by ResNet50**

# %%
# %%time
history=model.fit(
    X_train,y_train,
    batch_size= 32, validation_data=(X_test,y_test),
    epochs=400 , callbacks=[callbacks])
#validation_data=(X_test,y_test),
# Out:
# Epoch 1/400
# 132/132 [==============================] - 7s 38ms/step - loss: 0.9291 - accuracy: 0.4850 - val_loss: 0.8766 - val_accuracy: 0.5429
# Epoch 2/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.8533 - accuracy: 0.5410 - val_loss: 0.8604 - val_accuracy: 0.5381
# Epoch 3/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.8190 - accuracy: 0.5734 - val_loss: 0.8582 - val_accuracy: 0.5133
# Epoch 4/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.7867 - accuracy: 0.5993 - val_loss: 0.8446 - val_accuracy: 0.5324
# Epoch 5/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.7650 - accuracy: 0.6070 - val_loss: 0.9498 - val_accuracy: 0.5019
# Epoch 6/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.7507 - accuracy: 0.6134 - val_loss: 0.7204 - val_accuracy: 0.6400
# Epoch 7/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.7329 - accuracy: 0.6274 - val_loss: 0.6918 - val_accuracy: 0.6733
# Epoch 8/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.7142 - accuracy: 0.6353 - val_loss: 0.7097 - val_accuracy: 0.6552
# Epoch 9/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.6929 - accuracy: 0.6463 - val_loss: 0.8584 - val_accuracy: 0.5010
# Epoch 10/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.6834 - accuracy: 0.6613 - val_loss: 0.8592 - val_accuracy: 0.5067
# Epoch 11/400
# 132/132 [==============================] - 6s 43ms/step - loss: 0.6700 - accuracy: 0.6548 - val_loss: 0.6996 - val_accuracy: 0.6390
# Epoch 12/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.6516 - accuracy: 0.6777 - val_loss: 0.6857 - val_accuracy: 0.6638
# Epoch 13/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.6391 - accuracy: 0.6815 - val_loss: 0.6800 - val_accuracy: 0.6457
# Epoch 14/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.6277 - accuracy: 0.6958 - val_loss: 0.9066 - val_accuracy: 0.5867
# Epoch 15/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.6136 - accuracy: 0.6960 - val_loss: 1.0377 - val_accuracy: 0.5876
# Epoch 16/400
# 132/132 [==============================] - 4s 29ms/step - loss: 0.6039 - accuracy: 0.7113 - val_loss: 0.6653 - val_accuracy: 0.6467
# Epoch 17/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.5891 - accuracy: 0.7061 - val_loss: 0.6326 - val_accuracy: 0.6686
# Epoch 18/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.5784 - accuracy: 0.7275 - val_loss: 0.6254 - val_accuracy: 0.7057
# Epoch 19/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.5599 - accuracy: 0.7339 - val_loss: 0.6829 - val_accuracy: 0.6762
# Epoch 20/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0
400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0782 - accuracy: 0.9805 - val_loss: 0.3031 - val_accuracy: 0.8990
# Epoch 125/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0879 - accuracy: 0.9733 - val_loss: 0.3142 - val_accuracy: 0.8981
# Epoch 126/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0873 - accuracy: 0.9740 - val_loss: 0.3804 - val_accuracy: 0.8810
# Epoch 127/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0717 - accuracy: 0.9802 - val_loss: 0.7700 - val_accuracy: 0.8181
# Epoch 128/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1020 - accuracy: 0.9750 - val_loss: 0.7665 - val_accuracy: 0.7952
# Epoch 129/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0857 - accuracy: 0.9771 - val_loss: 0.4572 - val_accuracy: 0.8600
# Epoch 130/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.1068 - accuracy: 0.9736 - val_loss: 1.0017 - val_accuracy: 0.7810
# Epoch 131/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0732 - accuracy: 0.9769 - val_loss: 0.7209 - val_accuracy: 0.8124
# Epoch 132/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0835 - accuracy: 0.9719 - val_loss: 0.5273 - val_accuracy: 0.8562
# Epoch 133/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0692 - accuracy: 0.9786 - val_loss: 0.9173 - val_accuracy: 0.8248
# Epoch 134/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0918 - accuracy: 0.9783 - val_loss: 0.3768 - val_accuracy: 0.8705
# Epoch 135/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0785 - accuracy: 0.9814 - val_loss: 1.8546 - val_accuracy: 0.7048
# Epoch 136/400
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0882 - accuracy: 0.9807 - val_loss: 0.3800 - val_accuracy: 0.8800
# Epoch 137/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0917 - accuracy: 0.9778 - val_loss: 0.3280 - val_accuracy: 0.8810
# Epoch 138/400
# 132/132 [==============================] - 6s 47ms/step - loss: 0.0858 - accuracy: 0.9769 - val_loss: 0.3914 - val_accuracy: 0.8838
# Epoch 139/400
# 132/132 [==============================] - 6s 45ms/step - loss: 0.0715 - accuracy: 0.9812 - val_loss: 0.2913 - val_accuracy: 0.8962
# Epoch 140/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1210 - accuracy: 0.9745 - val_loss: 0.2623 - val_accuracy: 0.9029
# Epoch 141/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0762 - accuracy: 0.9800 - val_loss: 1.2677 - val_accuracy: 0.7410
# Epoch 142/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.1042 - accuracy: 0.9769 - val_loss: 0.3770 - val_accuracy: 0.8695
# Epoch 143/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0799 - accuracy: 0.9831 - val_loss: 1.0556 - val_accuracy: 0.7810
# Epoch 144/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1101 - accuracy: 0.9767 - val_loss: 0.6031 - val_accuracy: 0.8343
# Epoch 145/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0595 - accuracy: 0.9855 - val_loss: 0.2908 - val_accuracy: 0.9038
# Epoch 146/400
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0951 - accuracy: 0.9747 - val_loss: 0.2540 - val_accuracy: 0.9038
# Epoch 147/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0812 - accuracy: 0.9786 - val_loss: 0.5306 - val_accuracy: 0.8429
# Epoch 148/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0707 - accuracy: 0.9802 - val_loss: 0.6742 - val_accuracy: 0.8324
# Epoch 149/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0856 - accuracy: 0.9733 - val_loss: 0.2825 - val_accuracy: 0.9057
# Epoch 150/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0843 - accuracy: 0.9767 - val_loss: 0.4993 - val_accuracy: 0.8333
# Epoch 151/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.
400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0630 - accuracy: 0.9838 - val_loss: 0.6146 - val_accuracy: 0.8333
# Epoch 179/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0638 - accuracy: 0.9840 - val_loss: 0.3714 - val_accuracy: 0.8886
# Epoch 180/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0592 - accuracy: 0.9840 - val_loss: 0.2861 - val_accuracy: 0.9038
# Epoch 181/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0646 - accuracy: 0.9864 - val_loss: 0.2864 - val_accuracy: 0.9067
# Epoch 182/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.1051 - accuracy: 0.9740 - val_loss: 0.2949 - val_accuracy: 0.9048
# Epoch 183/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0514 - accuracy: 0.9867 - val_loss: 0.3381 - val_accuracy: 0.9038
# Epoch 184/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0600 - accuracy: 0.9859 - val_loss: 0.2610 - val_accuracy: 0.9181
# Epoch 185/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0933 - accuracy: 0.9807 - val_loss: 0.2695 - val_accuracy: 0.9095
# Epoch 186/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0845 - accuracy: 0.9824 - val_loss: 0.4285 - val_accuracy: 0.8733
# Epoch 187/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0557 - accuracy: 0.9840 - val_loss: 0.2857 - val_accuracy: 0.9057
# Epoch 188/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0756 - accuracy: 0.9840 - val_loss: 0.3356 - val_accuracy: 0.9029
# Epoch 189/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0657 - accuracy: 0.9809 - val_loss: 0.2775 - val_accuracy: 0.9200
# Epoch 190/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0586 - accuracy: 0.9879 - val_loss: 0.4765 - val_accuracy: 0.8810
# Epoch 191/400
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0911 - accuracy: 0.9783 - val_loss: 0.2601 - val_accuracy: 0.9105
# Epoch 192/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0804 - accuracy: 0.9819 - val_loss: 0.3253 - val_accuracy: 0.8952
# Epoch 193/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0764 - accuracy: 0.9836 - val_loss: 0.3910 - val_accuracy: 0.8905
# Epoch 194/400
# 132/132 [==============================] - 5s 41ms/step - loss: 0.0699 - accuracy: 0.9798 - val_loss: 0.2777 - val_accuracy: 0.9057
# Epoch 195/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0501 - accuracy: 0.9883 - val_loss: 0.2862 - val_accuracy: 0.9076
# Epoch 196/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0660 - accuracy: 0.9888 - val_loss: 0.4903 - val_accuracy: 0.8743
# Epoch 197/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0744 - accuracy: 0.9817 - val_loss: 0.3095 - val_accuracy: 0.9105
# Epoch 198/400
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0805 - accuracy: 0.9819 - val_loss: 0.5654 - val_accuracy: 0.8543
# Epoch 199/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0424 - accuracy: 0.9900 - val_loss: 0.2794 - val_accuracy: 0.9095
# Epoch 200/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.1147 - accuracy: 0.9800 - val_loss: 0.7678 - val_accuracy: 0.8333
# Epoch 201/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0547 - accuracy: 0.9836 - val_loss: 0.2908 - val_accuracy: 0.9114
# Epoch 202/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.1010 - accuracy: 0.9793 - val_loss: 1.4610 - val_accuracy: 0.7552
# Epoch 203/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0533 - accuracy: 0.9874 - val_loss: 0.6939 - val_accuracy: 0.8314
# Epoch 204/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0896 - accuracy: 0.9798 - val_loss: 0.3034 - val_accuracy: 0.9143
# Epoch 205/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0514 - accuracy: 0.9862 - val_loss: 0.3463 - val_accuracy: 0.8962
# Epoch 206/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0634 - accuracy: 0.9867 - val_loss: 0.2734 - val_accuracy: 0.9133
# Epoch 207/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0768 - accuracy: 0.9881 - val_loss: 0.7960 - val_accuracy: 0.8200
# Epoch 208/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0598 - accuracy: 0.9864 - val_loss: 0.2560 - val_accuracy: 0.9114
# Epoch 209/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0860 - accuracy: 0.9828 - val_loss: 0.9222 - val_accuracy: 0.8171
# Epoch 210/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0583 - accuracy: 0.9833 - val_loss: 0.2517 - val_accuracy: 0.9171
# Epoch 211/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0515 - accuracy: 0.9907 - val_loss: 0.2198 - val_accuracy: 0.9314
# Epoch 212/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0841 - accuracy: 0.9857 - val_loss: 0.3588 - val_accuracy: 0.8914
# Epoch 213/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0733 - accuracy: 0.9817 - val_loss: 0.2891 - val_accuracy: 0.9143
# Epoch 214/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0581 - accuracy: 0.9867 - val_loss: 0.2750 - val_accuracy: 0.9152
# Epoch 215/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0765 - accuracy: 0.9862 - val_loss: 0.5322 - val_accuracy: 0.8676
# Epoch 216/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0492 - accuracy: 0.9881 - val_loss: 0.2807 - val_accuracy: 0.9076
# Epoch 217/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0774 - accuracy: 0.9871 - val_loss: 0.3036 - val_accuracy: 0.9143
# Epoch 218/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0789 - accuracy: 0.9833 - val_loss: 0.4640 - val_accuracy: 0.8714
# Epoch 219/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0768 - accuracy: 0.9876 - val_loss: 0.3679 - val_accuracy: 0.8990
# Epoch 220/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0294 - accuracy: 0.9907 - val_loss: 0.3315 - val_accuracy: 0.9029
# Epoch 221/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0586 - accuracy: 0.9828 - val_loss: 0.2766 - val_accuracy: 0.9171
# Epoch 222/400
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0658 - accuracy: 0.9845 - val_loss: 0.4292 - val_accuracy: 0.8600
# Epoch 223/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0670 - accuracy: 0.9840 - val_loss: 0.2619 - val_accuracy: 0.9238
# Epoch 224/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0476 - accuracy: 0.9867 - val_loss: 0.4821 - val_accuracy: 0.8724
# Epoch 225/400
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0683 - accuracy: 0.9826 - val_loss: 0.2838 - val_accuracy: 0.9171
# Epoch 226/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0704 - accuracy: 0.9848 - val_loss: 0.3532 - val_accuracy: 0.8981
# Epoch 227/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0581 - accuracy: 0.9907 - val_loss: 0.3349 - val_accuracy: 0.9086
# Epoch 228/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0341 - accuracy: 0.9898 - val_loss: 0.4726 - val_accuracy: 0.8752
# Epoch 229/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0659 - accuracy: 0.9888 - val_loss: 0.2492 - val_accuracy: 0.9238
# Epoch 230/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0612 - accuracy: 0.9879 - val_loss: 0.7230 - val_accuracy: 0.8352
# Epoch 231/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0600 - accuracy: 0.9857 - val_loss: 0.2403 - val_accuracy: 0.9248
# Epoch 232/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0485 - accuracy: 0.9905 - val_loss: 0.8287 - val_accuracy: 0.8333
# Epoch 233/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0247 - accuracy: 0.9955 - val_loss: 0.2871 - val_accuracy: 0.9152
# Epoch 234/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0506 - accuracy: 0.9890 - val_loss: 0.4297 - val_accuracy: 0.8819
# Epoch 235/400
# 132/132 [==============================] - 6s 42ms/step - loss: 0.0697 - accuracy: 0.9840 - val_loss: 0.3791 - val_accuracy: 0.8943
# Epoch 236/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0292 - accuracy: 0.9938 - val_loss: 0.2976 - val_accuracy: 0.9171
# Epoch 237/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0744 - accuracy: 0.9824 - val_loss: 0.3223 - val_accuracy: 0.9143
# Epoch 238/400
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0490 - accuracy: 0.9893 - val_loss: 0.2918 - val_accuracy: 0.9152
# Epoch 239/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0787 - accuracy: 0.9864 - val_loss: 0.2872 - val_accuracy: 0.9143
# Epoch 240/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0639 - accuracy: 0.9862 - val_loss: 0.5033 - val_accuracy: 0.8629
# Epoch 241/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0417 - accuracy: 0.9898 - val_loss: 0.2691 - val_accuracy: 0.9181
# Epoch 242/400
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0848 - accuracy: 0.9807 - val_loss: 0.7216 - val_accuracy: 0.8619
# Epoch 243/400
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0550 - accuracy: 0.9857 - val_loss: 0.3214 - val_accuracy: 0.9067
# Epoch 244/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0572 - accuracy: 0.9881 - val_loss: 0.3721 - val_accuracy: 0.8876
# Epoch 245/400
# 132/132 [==============================] - 6s 42ms/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.3281 - val_accuracy: 0.9057
# Epoch 246/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0471 - accuracy: 0.9883 - val_loss: 0.3766 - val_accuracy: 0.8981
# Epoch 247/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0418 - accuracy: 0.9905 - val_loss: 0.8064 - val_accuracy: 0.8400
# Epoch 248/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0691 - accuracy: 0.9795 - val_loss: 0.9386 - val_accuracy: 0.7981
# Epoch 249/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0653 - accuracy: 0.9814 - val_loss: 0.2831 - val_accuracy: 0.9143
# Epoch 250/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0651 - accuracy: 0.9893 - val_loss: 0.3535 - val_accuracy: 0.9010
# Epoch 251/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0349 - accuracy: 0.9917 - val_loss: 0.2795 - val_accuracy: 0.9200
# Epoch 252/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0623 - accuracy: 0.9836 - val_loss: 0.5040 - val_accuracy: 0.8743
# Epoch 253/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0558 - accuracy: 0.9857 - val_loss: 0.2926 - val_accuracy: 0.9114
# Epoch 254/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0522 - accuracy: 0.9888 - val_loss: 0.5728 - val_accuracy: 0.8867
# Epoch 255/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0574 - accuracy: 0.9871 - val_loss: 0.2937 - val_accuracy: 0.9162
# Epoch 256/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0810 - accuracy: 0.9814 - val_loss: 0.2738 - val_accuracy: 0.9219
# Epoch 257/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0651 - accuracy: 0.9867 - val_loss: 0.2810 - val_accuracy: 0.9152
# Epoch 258/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0502 - accuracy: 0.9874 - val_loss: 0.2666 - val_accuracy: 0.9305
# Epoch 259/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0720 - accuracy: 0.9848 - val_loss: 0.3701 - val_accuracy: 0.9038
# Epoch 260/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0576 - accuracy: 0.9850 - val_loss: 0.4005 - val_accuracy: 0.8952
# Epoch 261/400
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0438 - accuracy: 0.9902 - val_loss: 0.2826 - val_accuracy: 0.9152
# Epoch 262/400
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0597 - accuracy: 0.9876 - val_loss: 1.0811 - val_accuracy: 0.8076
# Epoch 263/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0373 - accuracy: 0.9893 - val_loss: 0.2376 - val_accuracy: 0.9362
# Epoch 264/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0571 - accuracy: 0.9871 - val_loss: 0.5063 - val_accuracy: 0.8714
# Epoch 265/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0377 - accuracy: 0.9933 - val_loss: 1.1697 - val_accuracy: 0.7829
# Epoch 266/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0615 - accuracy: 0.9857 - val_loss: 0.6991 - val_accuracy: 0.8533
# Epoch 267/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0672 - accuracy: 0.9838 - val_loss: 0.2415 - val_accuracy: 0.9238
# Epoch 268/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0688 - accuracy: 0.9852 - val_loss: 0.5050 - val_accuracy: 0.8686
# Epoch 269/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.2719 - val_accuracy: 0.9257
# Epoch 270/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0745 - accuracy: 0.9855 - val_loss: 0.2434 - val_accuracy: 0.9305
# Epoch 271/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0525 - accuracy: 0.9869 - val_loss: 0.2597 - val_accuracy: 0.9248
# Epoch 272/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0379 - accuracy: 0.9940 - val_loss: 0.2521 - val_accuracy: 0.9352
# Epoch 273/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0595 - accuracy: 0.9867 - val_loss: 0.2939 - val_accuracy: 0.9190
# Epoch 274/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0419 - accuracy: 0.9945 - val_loss: 0.7963 - val_accuracy: 0.8438
# Epoch 275/400
# 132/132 [==============================] - 5s 39ms/step - loss: 0.0887 - accuracy: 0.9805 - val_loss: 0.5107 - val_accuracy: 0.8629
# Epoch 276/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0261 - accuracy: 0.9929 - val_loss: 0.2626 - val_accuracy: 0.9238
# Epoch 277/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0400 - accuracy: 0.9912 - val_loss: 0.3107 - val_accuracy: 0.9057
# Epoch 278/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0360 - accuracy: 0.9912 - val_loss: 0.2841 - val_accuracy: 0.9162
# Epoch 279/400
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0684 - accuracy: 0.9867 - val_loss: 0.3375 - val_accuracy: 0.8990
# Epoch 280/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0448 - accuracy: 0.9886 - val_loss: 0.4235 - val_accuracy: 0.8876
# Epoch 281/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0603 - accuracy: 0.9867 - val_loss: 0.2950 - val_accuracy: 0.9171
# Epoch 282/400
# 132/132 [==============================] - 5s 40ms/step - loss: 0.0499 - accuracy: 0.9917 - val_loss: 0.4234 - val_accuracy: 0.8990
# Epoch 283/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0762 - accuracy: 0.9859 - val_loss: 1.0318 - val_accuracy: 0.8229
# Epoch 284/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0750 - accuracy: 0.9869 - val_loss: 0.2769 - val_accuracy: 0.9295
# Epoch 285/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0880 - accuracy: 0.9778 - val_loss: 0.3020 - val_accuracy: 0.9143
# Epoch 286/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0449 - accuracy: 0.9895 - val_loss: 0.6983 - val_accuracy: 0.8552
# Epoch 287/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0321 - accuracy: 0.9909 - val_loss: 0.3002 - val_accuracy: 0.9181
# Epoch 288/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.
400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0571 - accuracy: 0.9914 - val_loss: 0.2841 - val_accuracy: 0.9324
# Epoch 342/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0554 - accuracy: 0.9848 - val_loss: 0.3128 - val_accuracy: 0.9257
# Epoch 343/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0638 - accuracy: 0.9852 - val_loss: 0.3132 - val_accuracy: 0.9200
# Epoch 344/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0499 - accuracy: 0.9898 - val_loss: 0.4303 - val_accuracy: 0.8990
# Epoch 345/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0287 - accuracy: 0.9929 - val_loss: 0.2983 - val_accuracy: 0.9219
# Epoch 346/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0565 - accuracy: 0.9895 - val_loss: 0.3327 - val_accuracy: 0.9190
# Epoch 347/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0401 - accuracy: 0.9926 - val_loss: 0.2920 - val_accuracy: 0.9343
# Epoch 348/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0199 - accuracy: 0.9957 - val_loss: 0.2900 - val_accuracy: 0.9210
# Epoch 349/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0572 - accuracy: 0.9902 - val_loss: 0.3237 - val_accuracy: 0.9171
# Epoch 350/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0617 - accuracy: 0.9845 - val_loss: 0.3200 - val_accuracy: 0.9114
# Epoch 351/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0311 - accuracy: 0.9929 - val_loss: 0.3116 - val_accuracy: 0.9229
# Epoch 352/400
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0539 - accuracy: 0.9867 - val_loss: 0.3124 - val_accuracy: 0.9238
# Epoch 353/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0734 - accuracy: 0.9871 - val_loss: 0.3865 - val_accuracy: 0.9010
# Epoch 354/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0354 - accuracy: 0.9917 - val_loss: 0.4862 - val_accuracy: 0.8914
# Epoch 355/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0626 - accuracy: 0.9843 - val_loss: 0.3339 - val_accuracy: 0.9162
# Epoch 356/400
# 132/132 [==============================] - 6s 42ms/step - loss: 0.0559 - accuracy: 0.9876 - val_loss: 0.5250 - val_accuracy: 0.8762
# Epoch 357/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0230 - accuracy: 0.9945 - val_loss: 0.3292 - val_accuracy: 0.9190
# Epoch 358/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0409 - accuracy: 0.9890 - val_loss: 0.6928 - val_accuracy: 0.8657
# Epoch 359/400
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0493 - accuracy: 0.9852 - val_loss: 0.4167 - val_accuracy: 0.8990
# Epoch 360/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0201 - accuracy: 0.9926 - val_loss: 0.2849 - val_accuracy: 0.9400
# Epoch 361/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0441 - accuracy: 0.9898 - val_loss: 0.8611 - val_accuracy: 0.8562
# Epoch 362/400
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0392 - accuracy: 0.9924 - val_loss: 1.2931 - val_accuracy: 0.8105
# Epoch 363/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0430 - accuracy: 0.9893 - val_loss: 0.9754 - val_accuracy: 0.8295
# Epoch 364/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0418 - accuracy: 0.9895 - val_loss: 0.3184 - val_accuracy: 0.9200
# Epoch 365/400
# 132/132 [==============================] - 4s 31ms/step - loss: 0.0663 - accuracy: 0.9890 - val_loss: 0.3360 - val_accuracy: 0.9190
# Epoch 366/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0656 - accuracy: 0.9871 - val_loss: 0.6599 - val_accuracy: 0.8648
# Epoch 367/400
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0300 - accuracy: 0.9957 - val_loss: 0.2677 - val_accuracy: 0.9276
# Epoch 368/400
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0436 - accuracy: 0.9895 - val_loss: 0.3409 - val_accuracy: 0.9171
# Epoch 369/400
# 132/132 [==============================] - 4s 34ms/step - loss: 0.0674 - accuracy: 0.9838 - val_loss: 0.2959 - val_accuracy: 0.9314
# Epoch 370/400
# 132/132 [==============================] - 5s 38ms/step - loss: 0.
# 132/132 [==============================] - 4s 32ms/step - loss: 4.4029e-06 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9390
# Epoch 396/400
# 132/132 [==============================] - 5s 35ms/step - loss: 3.9213e-06 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9400
# Epoch 397/400
# 132/132 [==============================] - 5s 38ms/step - loss: 3.5174e-06 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9410
# Epoch 398/400
# 132/132 [==============================] - 4s 31ms/step - loss: 3.1930e-06 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9410
# Epoch 399/400
# 132/132 [==============================] - 4s 31ms/step - loss: 2.8992e-06 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9419
# Epoch 400/400
# 132/132 [==============================] - 5s 40ms/step - loss: 2.7238e-06 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9419
# CPU times: user 37min 53s, sys: 1min 6s, total: 39min
# Wall time: 30min 24s

# %% [markdown]
# **Evaluation of ResNet50**

# %%
train_acc = model.evaluate(X_train, y_train, verbose=0)
test_acc = model.evaluate(X_test, y_test, verbose=0)

print ("Training Accuracy: [Loss, Accuracy]= " + str(train_acc))
print ("Testing Accuracy:[Loss, Accuracy]= " + str(test_acc))
# Out:
# Training Accuracy: [Loss, Accuracy]= [2.560718485256075e-06, 1.0]
# Testing Accuracy:[Loss, Accuracy]= [0.2645430564880371, 0.9419047832489014]

# %%
'''
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training' , 'Val_accuracy'], loc='lower right')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training' , 'Validation'], loc='upper right')
plt.show()

'''

# %%
plt.figure(figsize=(7.5,5))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy vs. epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training' , 'Val_accuracy'], loc='lower right')

plt.show()

# %%
plt.figure(figsize=(7.5,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training' , 'Validation'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn import metrics

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# 33/33 [==============================] - 0s 8ms/step
# [[141   7   2]
#  [  3 405  25]
#  [  1  23 443]]

# %%
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics

actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)

confusion_matrix = metrics.confusion_matrix(y_test, y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])

cm_display.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e2567bbdfd07> in <cell line: 12>()
#      10 cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
#      11
# ---> 12 cm_display.plot()
#      13 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_plot/confusion_matrix.py in plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw, text_kw)
#     179         if colorbar:
#     180             fig.colorbar(self.im_, ax=ax)
# --> 181         ax.set(
#     182             xticks=np.arange(n_classes),
#     183             yticks=np.arange(n_classes),
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in <lambda>(self, **kwargs)
#     145             return
#     146
# --> 147         cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     148         cls.set.__name__ = "set"
#     149         cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1229         # Artist._update_set_signature_and_docstring() at the end of the
#    1230         # module.
# -> 1231         return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#    1232
#    1233     @contextlib.contextmanager
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1221         The lack of prenormalization is to maintain backcompatibility.
#    1222         """
# -> 1223         return self._update_props(
#    1224             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225             "{prop_name!r}")
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1197                         raise AttributeError(
#    1198                             errfmt.format(cls=type(self), prop_name=k))
# -> 1199                     ret.append(func(v))
#    1200         if ret:
#    1201             self.pchanged()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1967             # remove all tick labels, so only error for > 0 labels
#    1968             if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 1969                 raise ValueError(
#    1970                     "The number of FixedLocator locations"
#    1971                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (3), usually from a call to set_ticks, does not match the number of labels (2).

# %%
accuracy = accuracy_score(y_test, y_pred )
print ('Accuracy: %.4f' % accuracy)
# Out:
# Accuracy: 0.9419

# %%
recall = recall_score(y_test, y_pred , average='macro' )
print ('Recall: %.4f' % recall)
# Out:
# Recall: 0.9413

# %%
precision = precision_score(y_test, y_pred , average='macro')
print ('Precision: %.4f' % precision)
# Out:
# Precision: 0.9487

# %%
f1score = f1_score(y_test, y_pred , average='macro' )
print ('F1-Score: %.4f' % f1score)
# Out:
# F1-Score: 0.9449

# %% [markdown]
# **Data Augmentation**

# %%
directory_train = "/content/drive/MyDrive/DataSet_CBIS-DDSM/Mass_Train_Set/"
directory_test = "/content/drive/MyDrive/DataSet_CBIS-DDSM/Mass_Test_Set/"
def get_ImageDataGenerator(validation_split=None):
    image_generator = ImageDataGenerator(rescale=(1/255.),
                                        validation_split=validation_split)
    return image_generator
image_gen_train = get_ImageDataGenerator(validation_split=0.2)
def get_generator(image_data_generator, directory, train_valid=None, seed=None):
    train_generator = image_data_generator.flow_from_directory(directory, batch_size=32, class_mode='categorical', target_size=(240,240), subset=train_valid, seed=seed)
    return train_generator
train_generator = get_generator(image_gen_train, directory_train, train_valid='training', seed=1)
validation_generator = get_generator(image_gen_train, directory_train, train_valid='validation')
# Out:
# Found 985 images belonging to 3 classes.
# Found 244 images belonging to 3 classes.

# %%
target_labels = next(os.walk(directory_train))[1]

target_labels.sort()

batch = next(train_generator)
batch_images = np.array(batch[0])
batch_labels = np.array(batch[1])

target_labels = np.asarray(target_labels)

plt.figure(figsize=(15,10))
for n, i in enumerate(np.arange(10)):
    ax = plt.subplot(3,5,n+1)
    plt.imshow(batch_images[i])
    plt.title(target_labels[np.where(batch_labels[i]==1)[0][0]])
    plt.axis('off')
